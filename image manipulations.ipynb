# %%
#importing libraries
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
#reading image
img = cv2.imread("car.jpg")
new_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(new_img)

# %%
#resizing image
re_img = cv2.resize(new_img,(1000,200))
plt.imshow(re_img)

# %%
#code for resizing image using ratios
width_ratio = 0.5
height_ratio = 0.5
r_img = cv2.resize(new_img,(0,0),new_img,width_ratio,height_ratio)
plt.imshow(r_img)

# %%
#flipping image
flip_img = cv2.flip(new_img,0)
plt.imshow(flip_iflimg)

# %%
#how to create and save a new image
cv2.imwrite("flip.jpg",flip_img)
# Out:
# True
